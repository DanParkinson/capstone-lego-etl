# %%
import pandas as pd

df = pd.read_csv("../data/processed/lego_clean.csv")

# %%
df.dtypes["list_price"]
repr(df.dtypes["list_price"])
# Out:
# "dtype('float64')"

# %%
df["list_price"].dtype
pd.api.types.is_float_dtype(df["list_price"])
# Out:
# True

# %%
df["theme_name"].nunique()
# Out:
# 41
