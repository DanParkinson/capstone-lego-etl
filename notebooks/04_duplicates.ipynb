# %% [markdown]
# # Duplicates

# %%
import pandas as pd

df = pd.read_csv("../data/raw/lego_sets_raw.csv")

# %%
df.duplicated().sum()
# df[df.duplicated()].head()
# Out:
# np.int64(1389)

# %%
df.shape[0]
# Out:
# 12261

# %% [markdown]
# ## Composite key or prod_id and country

# %%
df["prod_id"].isna().sum()
# Out:
# np.int64(0)

# %%
df["country"].isna().sum()
# Out:
# np.int64(0)

# %%
df.duplicated(subset=["prod_id", "country"]).sum()
# Out:
# np.int64(1391)

# %%
# Out:
#      ages  list_price  num_reviews  piece_count  play_star_rating  \
# 15    10+       19.99          1.0        234.0               3.0
# 576  9-14       69.99         19.0        944.0               3.6
# 533  5-12       39.99         10.0        169.0               4.3
# 534    5+        3.99         13.0          8.0               4.3
# 535    5+        3.99         22.0          8.0               4.3
#
#                                              prod_desc  prod_id  \
# 15   Train a raptor with LEGO® BrickHeadz™ Owen and...  41614.0
# 576  Put the heat on the shark army with Kai’s Fire...  70615.0
# 533         Pack your city with a bunch of new people!  60153.0
# 534  Discover new heroes and villains in LEGO® Mini...  71020.0
# 535  Bring the NINJAGO® world to life with LEGO® Mi...  71019.0
#
#                                         prod_long_desc review_difficulty  \
# 15   These LEGO® BrickHeadz™ 41614 Owen & Blue cons...              Easy
# ...
